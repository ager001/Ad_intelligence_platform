# %%
# Import all required libraries
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
# Loading of the clean data
df = pd.read_csv("../data/processed/ad_click_clean_featured_engineered.csv")

df.head()
# Out:
#     age      gender device_type ad_position time_of_day  click
# 0  22.0     Unknown     Desktop         Top   Afternoon      1
# 1  39.5        Male     Desktop         Top     Unknown      1
# 2  41.0  Non-Binary     Unknown        Side       Night      1
# 3  34.0        Male     Unknown     Unknown     Evening      1
# 4  39.0  Non-Binary     Unknown     Unknown     Morning      0
