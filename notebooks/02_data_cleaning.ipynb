# %% [markdown]
# # Data Cleaning
#
# Objective:
# Prepare the dataset for machine learning by handling missing values,
# duplicates, incorrect data types, and inconsistencies.

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Projects\ML_PROJECTS\Ad_intelligence_platform\data\raw\ad_click.csv")

# %%
df.head()

# %%
print("Rows and Columns:")
print(df.shape)

print("\nColumn Names:")
print(df.columns)

print("\nData Types:")
print(df.dtypes)

# %% [markdown]
# Rows and Columns:
# (10000, 9)
#
# Column Names:
# Index(['id', 'full_name', 'age', 'gender', 'device_type', 'ad_position',
#        'browsing_history', 'time_of_day', 'click'],
#       dtype='str')
#
# Data Types:
# id                    int64
# full_name               str
# age                 float64
# gender                  str
# device_type             str
# ad_position             str
# browsing_history        str
# time_of_day             str
# click                 int64
# dtype: object

# %%
missing = df.isnull().sum()

missing[missing > 0]

# %% [markdown]
# # Means 4766 ages, gender 4693, device_type 2000, ad_position 2000, browsing_history 4782, time_of_day 2000
# # inshort these are all missing values that we have
#
# age                 4766
# gender              4693
# device_type         2000
# ad_position         2000
# browsing_history    4782
# time_of_day         2000
# dtype: int64

# %%
duplicates = df.duplicated().sum()

print("Duplicate Rows:", duplicates)

# %% [markdown]
# # Duplicate Rows: 2853

# %%
for col in df.columns:
    print(f"\n{col}")
    print(df[col].unique())

# %% [markdown]
# # These are all inconsistencies and we should find them and standardize them
#
# id
# [ 670 3044 5912 ... 7843 3914 3056]
#
# full_name
# <StringArray>
# [ 'User670', 'User3044', 'User5912', 'User5418', 'User9452', 'User5942',
#  'User7808', 'User5065', 'User7993', 'User4509',
#  ...
#  'User9871',  'User545', 'User8337', 'User2750', 'User2713', 'User9540',
#  'User8510', 'User7843', 'User3914', 'User3056']
# Length: 4000, dtype: str
#
# age
# [22. nan 41. 34. 39. 26. 40. 47. 19. 56. 24. 52. 42. 36. 43. 62. 45. 37.
#  31. 58. 59. 48. 38. 49. 30. 46. 54. 44. 27. 57. 28. 51. 25. 61. 32. 64.
#  23. 55. 21. 20. 35. 53. 33. 29. 63. 50. 18. 60.]
#
# gender
# <StringArray>
# [nan, 'Male', 'Non-Binary', 'Female']
# Length: 4, dtype: str

# %%
df["gender"].value_counts()

# %%
df["device_type"].value_counts()

# %%
df["ad_position"].value_counts()

# %%
df["time_of_day"].value_counts()
