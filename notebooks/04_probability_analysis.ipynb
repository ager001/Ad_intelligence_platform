# %%
# Importation of Libraries
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loaded the dataset from processed folder. This dataset has already been featured engineered

df_encoded = pd.read_csv("../data/processed/ad_click_clean_featured_engineered.csv")

df_encoded.head()

# %%
# Calculation of overall click probability

click_probability = df_encoded["click"].mean()

print(click_probability)

# %%
# Expressing the overall click probability as a percentage
click_percentage = click_probability * 100

print(f"Click Rate: {click_percentage:.2f}%")

# %%
# Visualization of the click probability

sns.countplot(x="click", data=df_encoded)

plt.title("Distribution of Clicks")
plt.show()

# %%
# Confirmation of columns
df_encoded.columns

# %%
# Gender Probability
df_encoded.groupby("gender")["click"].mean()

# %%
# Device Type probability
df_encoded.groupby("device_type")["click"].mean()

# %%
df_encoded.groupby("ad_position")["click"].mean()
